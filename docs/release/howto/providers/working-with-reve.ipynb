# %% [markdown]
# # Working with Reve in Pixeltable
#
# Pixeltable's Reve integration lets you call Reve's image generation API directly from tables so you can iterate on visuals without leaving your data workflows.
#
# ## What is Reve?
#
# Reve is an image generation and editing service. In its v2 API, the previously separate `create`, `edit`, and `remix` operations are unified into a single `create` endpoint, so Pixeltable exposes just **one** UDF: `reve.create()`. Depending on what you pass it, the same function covers three use cases:
#
# - **Generate** a brand-new image from a text prompt.
# - **Edit** an existing image by passing it as a single reference.
# - **Remix** several images together by passing multiple references.
#
# You attach reference images with the `references` argument and point to them from the prompt with `<frame>0</frame>`, `<frame>1</frame>`, etc. (0-indexed, in the order you pass them).
#
# `reve.create()` returns a dictionary with two keys: `'image'` (the generated image) and `'layout'` (JSON metadata describing the generated image, such as the prompt and the regions Reve laid out). In this notebook we only need the image, so we index into the result with `['image']`.
#
# ### Documentation
#
# - [Pixeltable Reve Functions](https://docs.pixeltable.com/sdk/latest/reve#module-pixeltable-functions-reve)
# - [Reve API Reference](https://api.reve.com/console/docs)
#
# ## Prerequisites
#
# - A Reve account with an API key (see <https://api.reve.com/> for instructions)
#
# **Important:** Reve API calls consume credits based on your plan—monitor your usage to avoid unexpected charges. Images sent to Reve are processed on Reve's servers outside your environment, so do not upload sensitive, private, or confidential images.
#
# We'll start by installing Pixeltable, configuring your API key, creating a directory, and setting up a table. Then we'll walk through each use case of `reve.create()`—generate, edit, and remix—one at a time.

# %%
# %pip install -qU pixeltable

# %%
import getpass
import os

if 'REVE_API_KEY' not in os.environ:
    os.environ['REVE_API_KEY'] = getpass.getpass('Reve API Key: ')

# %% [markdown]
# To read more about working with API keys in Pixeltable, see [Configuration](https://docs.pixeltable.com/platform/configuration).

# %% [markdown]
# ## Setup

# %% [markdown]
# Create a Pixeltable directory to keep the tables for this demo separate from anything else you're working on.

# %%
import pixeltable as pxt

pxt.create_dir('reve_demo', if_exists='replace_force')
# Out:
# Connected to Pixeltable database at: postgresql+psycopg://postgres:@/pixeltable?host=/Users/sergeymkhitaryan/.pixeltable/pgdata
# Created directory 'reve_demo'.

# %% [markdown]
# We'll create a Pixeltable table that starts with a prompt and a source image, and ends with a final scene. The table we'll build up to will require two inputs per row:
#
# 1. A prompt for creating a background scene image. We'll pass this prompt to `reve.create()` to generate a scene.
# 1. An existing source image. We'll pass this image to `reve.create()` as a single reference to edit it, and then it will be ready as the foreground image.
#
# Finally, we'll pass both the background scene and the edited foreground image to `reve.create()` as multiple references to remix them into one final scene.

# %%
spunk_t = pxt.create_table(
    'reve_demo/solarpunk_scenes',
    {'prompt': pxt.String, 'source_image': pxt.Image},
)
# Out:
# Created table 'solarpunk_scenes'.

# %% [markdown]
# To read more about creating tables, see [Tables and Data Operations](https://docs.pixeltable.com/tutorials/tables-and-data-operations).

# %% [markdown]
# You can look at the schema for this table:

# %%
spunk_t.describe()
# Out:
# <style type="text/css">
# #T_1775b_row0_col0 {
#   white-space: pre-wrap;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_1775b">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1775b_row0_col0" class="data row0 col0" >table 'reve_demo/solarpunk_scenes'</td>
#     </tr>
#   </tbody>
# </table>
#
# <style type="text/css">
# #T_293d0 th {
#   text-align: left;
#   border-bottom: 2px solid #666;
# }
# #T_293d0_row0_col0, #T_293d0_row0_col1, #T_293d0_row0_col2, #T_293d0_row0_col3, #T_293d0_row0_col4, #T_293d0_row1_col0, #T_293d0_row1_col1, #T_293d0_row1_col2, #T_293d0_row1_col3, #T_293d0_row1_col4 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_293d0">
#   <thead>
#     <tr>
#       <th id="T_293d0_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_293d0_level0_col1" class="col_heading level0 col1" >Type</th>
# ...

# %% [markdown]
# Now, we'll insert values for our first row. We need to provide a text prompt to generate a scene and a source image to edit.

# %%
scene_prompt = (
    'Create a scene of lush solarpunk metropolis in the desert '
    'with urban agriculture and an oasis theme.'
    'It should not look like an office park, corporate campus, or an outdoor mall.'
)

image_url = 'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/resources/images/000000000036.jpg'

# %%
spunk_t.insert([{'prompt': scene_prompt, 'source_image': image_url}])
# Out:
# Inserted 1 row with 0 errors in 0.04 s (28.19 rows/s)
# 1 row inserted.

# %% [markdown]
# To read more about inserting data, see [Bringing Data](https://docs.pixeltable.com/howto/cookbooks/data/data-import-csv).

# %% [markdown]
# And we can peek at our starter table with a single row:

# %%
spunk_t.collect()
# Out:
#                                               prompt  \
# 0  Create a scene of lush solarpunk metropolis in...
#
#                                         source_image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ## Generate new imagery from a prompt
#
# Use `reve.create()` with just a prompt when you want Reve to synthesize an entirely new image. In Pixeltable, we place this function call inside a computed column. Feel free to change the prompt. Here we ask for a solarpunk oasis city.
#
# Since `reve.create()` returns a dictionary, we index it with `['image']` so the `new_image` column holds the generated image itself (stored as a proper image, with a file URL, thumbnails, and so on).
#
# Reve's raw outputs can be large, so we pass a `postprocessing` step that downscales each generated image to at most 1024 pixels on its longest side. We define it once and reuse it for every `reve.create()` call below.

# %%
from pixeltable.functions import reve

# Downscale generated images so their longest side is at most 1024 pixels
fit_1024 = [{'process': 'fit_image', 'max_dim': 1024}]

spunk_t.add_computed_column(
    new_image=reve.create(spunk_t.prompt, postprocessing=fit_1024)[
        'image'
    ],
    if_exists='replace',
)
# Out:
# Added 1 column value with 0 errors in 46.36 s (0.02 rows/s)
# 1 row updated.

# %% [markdown]
# To read more about computed columns in Pixeltable, see [Computed Columns](https://docs.pixeltable.com/tutorials/computed-columns).

# %%
spunk_t.select(spunk_t.prompt, spunk_t.new_image).collect()
# Out:
#                                               prompt  \
# 0  Create a scene of lush solarpunk metropolis in...
#
#                                            new_image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# By default, Pixeltable saves all generated media outputs to a media directory. We can see the file path by using the `fileurl` property.

# %%
spunk_t.select(spunk_t.new_image.fileurl).collect()
# Out:
#                                    new_image_fileurl
# 0  file:///Users/sergeymkhitaryan/.pixeltable/med...

# %% [markdown]
# ### Add Reve parameters
#
# `reve.create()` accepts several optional parameters to customize the output:
#
# - `aspect_ratio`: desired image aspect ratio, e.g. '3:2', '16:9', '1:1', etc.
# - `version`: specific model version to use (defaults to latest if not specified).
# - `postprocessing`: a list of postprocessing operations to apply to the generated image. We're already using it to downscale images (`fit_1024` above); other operations include effects, e.g. `[{'process': 'effect', 'effect_name': 'low_light'}]`.
# - `model_kwargs`: additional keyword arguments to pass through to the Reve API.
#
# This adds a second image column using the same prompt that renders in a square frame.

# %%
spunk_t.add_computed_column(
    new_image_sq=reve.create(
        spunk_t.prompt, aspect_ratio='1:1', postprocessing=fit_1024
    )['image'],
    if_exists='replace',
)
# Out:
# Added 1 column value with 0 errors in 58.36 s (0.02 rows/s)
# 1 row updated.

# %%
spunk_t.select(
    spunk_t.prompt, spunk_t.new_image, spunk_t.new_image_sq
).collect()
# Out:
#                                               prompt  \
# 0  Create a scene of lush solarpunk metropolis in...
#
#                                            new_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                         new_image_sq
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# To read more about `reve.create()`, see [reve.create UDF](https://docs.pixeltable.com/sdk/latest/reve#udf-create).

# %% [markdown]
# ## Edit an existing photo with a single reference
#
# When you pass a single image in `references` and refer to it from the prompt with `<frame>0</frame>`, `reve.create()` behaves like an editor: it transforms that image according to your natural-language instructions. We already have a `source_image` column in our table from the initial setup.

# %%
spunk_t.select(spunk_t.source_image).collect()
# Out:
#                                         source_image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# We can now add a computed column that calls `reve.create()` with `references=[spunk_t.source_image]` to modify the source image, indexing the result with `['image']` as before.
#
# This editing prompt is integrated into our computed column logic in Pixeltable, as opposed to our generate example where we saved the prompt as its own column. This means that the same prompt will be applied to any new rows that we insert into this table. We will phrase the editing prompt to reflect this table's solarpunk theme, but otherwise keep it general. This way, we don't need to provide a specific prompt for every new table row.

# %%
spunk_t.add_computed_column(
    edited_subject=reve.create(
        'Take <frame>0</frame>. Remove any existing background. Focus on the closest person in the foreground. '
        'Keep the person and props, but make the lighting and colors vibrant and fit with a solarpunk theme. '
        'Make the background behind the person blank.',
        references=[spunk_t.source_image],
        postprocessing=fit_1024,
    )['image'],
    if_exists='replace',
)
# Out:
# Added 1 column value with 0 errors in 58.24 s (0.02 rows/s)
# 1 row updated.

# %% [markdown]
# We can use `collect()` to see the new image:

# %%
spunk_t.select(spunk_t.source_image, spunk_t.edited_subject).collect()
# Out:
#                                         source_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                       edited_subject
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ## Remix multiple references
#
# When you pass multiple images in `references`, `reve.create()` blends them together. Inside the prompt string, you reference each image with a numbered `<frame>` placeholder, matching the order of the `references` list:
#
# - `<frame>0</frame>` refers to `references[0]`
# - `<frame>1</frame>` refers to `references[1]`
# - etc.
#
# You can optionally specify `aspect_ratio`, `version`, and other parameters just like before.
#
# In the next cell we place the edited subject from `<frame>0</frame>` (the first entry in the references list) into the scene from `<frame>1</frame>` (the second entry). Because `new_image` and `edited_subject` are already extracted image columns, we can pass them directly as references.

# %%
spunk_t.add_computed_column(
    solarpunk_remix=reve.create(
        'Place the person in <frame>0</frame> in the foreground of the scene from <frame>1</frame>. '
        'Make the background clear and detailed so it feels like a complete "day in the life" in solarpunk city scene.',
        references=[spunk_t.edited_subject, spunk_t.new_image],
        aspect_ratio='16:9',
        postprocessing=fit_1024,
    )['image'],
    if_exists='replace',
)
# Out:
# Added 1 column value with 0 errors in 76.41 s (0.01 rows/s)
# 1 row updated.

# %% [markdown]
# To read more about `reve.create()`, see [reve.create UDF](https://docs.pixeltable.com/sdk/latest/reve#udf-create).

# %%
spunk_t.select(spunk_t.solarpunk_remix).collect()
# Out:
#                                      solarpunk_remix
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ## Insert a new row

# %% [markdown]
# So far, we have been building up our table schema with a single row. Now we'll insert a new row, with two fresh input values:
#
# 1. A text prompt to generate the scene image and
# 1. A source image to edit and then remix into that scene.
#
# Pixeltable will then automatically make the desired Reve API calls and populate the computed columns.

# %%
spunk_t.insert(
    [
        {
            'prompt': 'Create an indoor tennis court scene, with clay courts inside a lush solarpunk greenhouse filled with bougainvillea, terraced gardens, and an oasis theme.',
            'source_image': 'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/resources/images/000000000885.jpg',
        }
    ]
)
# Out:
# Inserted 1 row with 0 errors in 153.10 s (0.01 rows/s)
# 1 row inserted.

# %% [markdown]
# Now we can inspect both outputs because the `insert()` in Pixeltable triggers our computed columns to update for any that are missing values (existing images we already generated are not changed because Pixeltable does incremental updates). For example, here is our inserted image and our edited image:

# %%
spunk_t.select(spunk_t.source_image, spunk_t.edited_subject).collect()
# Out:
#                                         source_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                       edited_subject
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# Here are our two remixed images created by Reve:

# %%
spunk_t.select(spunk_t.solarpunk_remix).collect()
# Out:
#                                      solarpunk_remix
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# All together, we generated a new scene image, edited an existing image of a person, then remixed both together to reimagine an existing person in our new scene.

# %%
spunk_t.select(
    spunk_t.new_image, spunk_t.edited_subject, spunk_t.solarpunk_remix
).collect()
# Out:
#                                            new_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                       edited_subject  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                      solarpunk_remix
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ## Review Reve in Pixeltable
#
# Below is a quick recap of the three ways we used the single `reve.create()` UDF inside Pixeltable tables. Each call reads input parameters and, after indexing the result with `['image']`, writes the generated image into a computed column.

# %% [markdown]
# ### Generate (prompt only)
#
# - **Input parameter:** A prompt inserted as a row inside a Pixeltable

# %%
spunk_t.select(
    spunk_t.prompt, spunk_t.new_image, spunk_t.new_image_sq
).collect()
# Out:
#                                               prompt  \
# 0  Create a scene of lush solarpunk metropolis in...
# 1  Create an indoor tennis court scene, with clay...
#
#                                            new_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                         new_image_sq
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ### Edit (one reference)
#
# - **Input parameter:** A source image of type `pxt.Image`, passed as `references=[...]`
# - **Usage reminder:** The edit instructions live inline inside the `add_computed_column()` call, and refer to the image with `<frame>0</frame>`

# %%
spunk_t.select(spunk_t.source_image, spunk_t.edited_subject).collect()
# Out:
#                                         source_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                       edited_subject
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ### Remix (multiple references)
#
# - **Input parameters:** We started with two image columns
# - **How the prompt references them:**
#   - `references=[my_table.image00, my_table.image01]`
#   - Inside the prompt, `<frame>0</frame>` points at `references[0]` and `<frame>1</frame>` points at `references[1]`
# - **Usage reminder:** Always keep the placeholders and the order of the `references` list in sync; add more `<frame>n</frame>` tags if you pass more reference images.

# %%
spunk_t.select(
    spunk_t.new_image, spunk_t.edited_subject, spunk_t.solarpunk_remix
).collect()
# Out:
#                                            new_image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                       edited_subject  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                      solarpunk_remix
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ## Learn more
#
# - Reve API reference: <https://api.reve.com/console/docs>
# - Pixeltable documentation: <https://docs.pixeltable.com/sdk/latest/reve#module-pixeltable-functions-reve>
#
# If you build something with Reve, let us know!
