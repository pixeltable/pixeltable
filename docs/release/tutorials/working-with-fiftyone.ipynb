# %% [markdown]
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/pixeltable/pixeltable/blob/release/docs/release/tutorials/working-with-voxel51.ipynb)&nbsp;&nbsp;
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pixeltable/pixeltable/blob/release/docs/release/tutorials/working-with-voxel51.ipynb)&nbsp;&nbsp;
# <a href="https://raw.githubusercontent.com/pixeltable/pixeltable/release/docs/release/tutorials/working-with-voxel51.ipynb" download><img src="https://img.shields.io/badge/%E2%AC%87-Download%20Notebook-blue" alt="Download Notebook"></a>
#
# # Working with Voxel51 in Pixeltable

# %% [markdown]
# Pixeltable can export data directly from tables and views to the popular [Voxel51](https://voxel51.com/) frontend, providing a way to visualize and explore image and video datasets. In this tutorial, we'll learn how to:
# - Export data from Pixeltable to Voxel51
# - Apply labels from image classification and object detection models to exported data
#
# We begin by installing the necessary libraries for this tutorial.

# %%
# %pip install -qU pixeltable fiftyone transformers

# %% [markdown]
# ## Example 1: An Image Dataset

# %%
import fiftyone as fo
import pixeltable as pxt

# Create a Pixeltable directory for the demo. We first drop the directory if it
# exists, in order to ensure a clean environment.

pxt.drop_dir('fo_demo', force=True)
pxt.create_dir('fo_demo')
# Out:
# Connected to Pixeltable database at: postgresql+psycopg://postgres:@/pixeltable?host=/Users/asiegel/.pixeltable/pgdata
# Created directory `fo_demo`.

# %%
# Create a Pixeltable table for our dataset and insert some sample images.

url_prefix = 'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/source/data/images'

urls = [
    'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/source/data/images/000000000019.jpg',
    'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/source/data/images/000000000025.jpg',
    'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/source/data/images/000000000030.jpg',
    'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/source/data/images/000000000034.jpg',
]

t = pxt.create_table('fo_demo.images', {'image': pxt.Image})
t.insert({'image': url} for url in urls)
t.head()
# Out:
# Created table `images`.
# Inserting rows into `images`: 4 rows [00:00, 1415.92 rows/s]
# Inserted 4 rows with 0 errors.
#                                                image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# Now we export our new table to a Voxel51 dataset and load it into a new Voxel51 session within our demo notebook. Once it's been loaded, the images can be interactively navigated as with any other Voxel51 dataset.

# %%
fo_dataset = pxt.io.export_images_as_fiftyone(t, t.image)
session = fo.launch_app(fo_dataset)
# Out:
#  100% |█████████████████████| 4/4 [21.3ms elapsed, 0s remaining, 187.4 samples/s]
# INFO:eta.core.utils: 100% |█████████████████████| 4/4 [21.3ms elapsed, 0s remaining, 187.4 samples/s]
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-797297da-5c8c-4505-ba64-88948a2b497d {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-797297da-5c8c-4505-ba64-88948a2b497d {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-797297da-5c8c-4505-ba64-88948a2b497d:focus {
#   outline: none;
# }
# #fooverlay-797297da-5c8c-4505-ba64-88948a2b497d {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-797297da-5c8c-4505-ba64-88948a2b497d">
#    <div id="fooverlay-797297da-5c8c-4505-ba64-88948a2b497d" style="display: none;">
#       <button id="foactivate-797297da-5c8c-4505-ba64-88948a2b497d" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 2745px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-797297da-5c8c-4505-ba64-88948a2b497d");
#      var overlay = document.getElementById("fooverlay-797297da-5c8c-4505-ba64-88948a2b497d");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "797297da-5c8c-4505-ba64-88948a2b497d" },
#               subscription: "797297da-5c8c-4505-ba64-88948a2b497d"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %% [markdown]
# ## Adding Labels

# %% [markdown]
# We'll now show how Voxel51 labels can be attached to the exported dataset. Currently, Pixeltable supports only classification and detection labels; other Voxel51 label types may be added in the future.
#
# First, let's generate some labels by applying two models from the Huggingface `transformers` library: A ViT model for image classification and a DETR model for object detection.

# %%
from pixeltable.functions.huggingface import vit_for_image_classification, detr_for_object_detection

t.add_column(classifications=vit_for_image_classification(
    t.image, model_id='google/vit-base-patch16-224'
))
t.add_column(detections=detr_for_object_detection(
    t.image, model_id='facebook/detr-resnet-50'
))
# Out:
# Computing cells: 100%|████████████████████████████████████████████| 4/4 [00:01<00:00,  3.90 cells/s]
# Added 4 column values with 0 errors.
# Computing cells: 100%|████████████████████████████████████████████| 4/4 [00:01<00:00,  3.31 cells/s]
# Added 4 column values with 0 errors.
# UpdateStatus(num_rows=4, num_computed_values=4, num_excs=0, updated_cols=[], cols_with_excs=[])

# %% [markdown]
# Both models output JSON containing the model results. Let's peek at the contents of our table now:

# %%
t.head()
# Out:
#                                                image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                      classifications  \
# 0  {'labels': [345, 690, 912, 346, 730], 'scores'...
# 1  {'labels': [340, 353, 386, 9, 352], 'scores': ...
# 2  {'labels': [883, 738, 708, 725, 716], 'scores'...
# 3  {'labels': [340, 353, 386, 352, 9], 'scores': ...
#
#                                           detections
# 0  {'boxes': [[335.8553771972656, 43.413597106933...
# 1  {'boxes': [[51.96046829223633, 356.18701171875...
# 2  {'boxes': [[238.07403564453125, 155.5013275146...
# 3  {'boxes': [[-0.230712890625, 19.50192070007324...

# %% [markdown]
# Now we need to transform our model data into the format the Voxel51 API expects (see the Pixeltable documentation for [pxt.io.export_as_fiftyone](https://pixeltable.github.io/pixeltable/api/io/#pixeltable.io.export_as_fiftyone) for details). We'll use Pixeltable UDFs to do the appropriate conversions.

# %%
@pxt.udf
def vit_to_fiftyone(vit_labels: list) -> list:
    return [
        {'label': label, 'confidence': score}
        for label, score in zip(vit_labels['label_text'], vit_labels['scores'])
    ]

@pxt.udf
def detr_to_fiftyone(img: pxt.Image, detr_labels: dict) -> list:
    result = []
    for label, box, score in zip(detr_labels['label_text'], detr_labels['boxes'], detr_labels['scores']):
        # DETR gives us bounding boxes in (x1,y1,x2,y2) absolute (pixel) coordinates.
        # Voxel51 expects (x,y,w,h) relative (fractional) coordinates.
        # So we need to do a conversion.
        fo_box = [
            box[0] / img.width,
            box[1] / img.height,
            (box[2] - box[0]) / img.width,
            (box[3] - box[1]) / img.height,
        ]
        result.append({'label': label, 'bounding_box': fo_box, 'confidence': score})
    return result

# %% [markdown]
# We can test that our UDFs are working as expected with a `select()` statement.

# %%
t.select(
    t.image,
    t.classifications,
    vit_to_fiftyone(t.classifications),
    t.detections,
    detr_to_fiftyone(t.image, t.detections)
).head()
# Out:
#                                                image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                      classifications  \
# 0  {'labels': [345, 690, 912, 346, 730], 'scores'...
# 1  {'labels': [340, 353, 386, 9, 352], 'scores': ...
# 2  {'labels': [883, 738, 708, 725, 716], 'scores'...
# 3  {'labels': [340, 353, 386, 352, 9], 'scores': ...
#
#                                      vit_to_fiftyone  \
# 0  [{'label': 'ox', 'confidence': 0.7670010328292...
# 1  [{'label': 'zebra', 'confidence': 0.3253521025...
# 2  [{'label': 'vase', 'confidence': 0.63610780239...
# 3  [{'label': 'zebra', 'confidence': 0.9953896999...
#
#                                           detections  \
# 0  {'boxes': [[335.8553771972656, 43.413597106933...
# 1  {'boxes': [[51.96046829223633, 356.18701171875...
# 2  {'boxes': [[238.07403564453125, 155.5013275146...
# 3  {'boxes': [[-0.230712890625, 19.50192070007324...
#
#                                     detr_to_fiftyone
# 0  [{'label': 'person', 'bounding_box': [0.524774...
# 1  [{'label': 'giraffe', 'bounding_box': [0.08118...
# 2  [{'label': 'vase', 'bounding_box': [0.37199068...
# 3  [{'label': 'zebra', 'bounding_box': [-0.000360...

# %% [markdown]
# Now we pass the modified structures to `export_as_fiftyone`.

# %%
fo_dataset = pxt.io.export_images_as_fiftyone(
    t,
    t.image,
    classifications=vit_to_fiftyone(t.classifications),
    detections=detr_to_fiftyone(t.image, t.detections)
)
session = fo.launch_app(fo_dataset)
# Out:
#  100% |█████████████████████| 4/4 [67.4ms elapsed, 0s remaining, 59.3 samples/s]
# INFO:eta.core.utils: 100% |█████████████████████| 4/4 [67.4ms elapsed, 0s remaining, 59.3 samples/s]
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-e5c42a18-b223-4d37-aaff-1e4f441b1538 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-e5c42a18-b223-4d37-aaff-1e4f441b1538 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-e5c42a18-b223-4d37-aaff-1e4f441b1538:focus {
#   outline: none;
# }
# #fooverlay-e5c42a18-b223-4d37-aaff-1e4f441b1538 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-e5c42a18-b223-4d37-aaff-1e4f441b1538">
#    <div id="fooverlay-e5c42a18-b223-4d37-aaff-1e4f441b1538" style="display: none;">
#       <button id="foactivate-e5c42a18-b223-4d37-aaff-1e4f441b1538" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 2745px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-e5c42a18-b223-4d37-aaff-1e4f441b1538");
#      var overlay = document.getElementById("fooverlay-e5c42a18-b223-4d37-aaff-1e4f441b1538");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "e5c42a18-b223-4d37-aaff-1e4f441b1538" },
#               subscription: "e5c42a18-b223-4d37-aaff-1e4f441b1538"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %% [markdown]
# ## Adding Multiple Label Sets
#
# You can include multiple label sets of the same type in the same dataset by passing a `list` or `dict` of expressions to the `classifications` and/or `detections` parameters. If a `list` is specified, default names will be assigned to the label sets; if a `dict` is specified, the label sets will be named according to its keys.
#
# As an example, let's try recomputing our detections using the more powerful DETR model ResNet-101, and then load them into the same Voxel51 dataset as the earlier detections in order to compare them side-by-side.

# %%
t.add_column(detections_101=detr_for_object_detection(
    t.image, model_id='facebook/detr-resnet-101'
))
# Out:
# Computing cells: 100%|████████████████████████████████████████████| 4/4 [00:01<00:00,  2.31 cells/s]
# Added 4 column values with 0 errors.
# UpdateStatus(num_rows=4, num_computed_values=4, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
fo_dataset = pxt.io.export_images_as_fiftyone(
    t,
    t.image,
    classifications=vit_to_fiftyone(t.classifications),
    detections={
        'detections_50': detr_to_fiftyone(t.image, t.detections),
        'detections_101': detr_to_fiftyone(t.image, t.detections_101)
    }
)
session = fo.launch_app(fo_dataset)
# Out:
#  100% |█████████████████████| 4/4 [73.7ms elapsed, 0s remaining, 54.3 samples/s]
# INFO:eta.core.utils: 100% |█████████████████████| 4/4 [73.7ms elapsed, 0s remaining, 54.3 samples/s]
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=bd9fde7e-6d0f-44f9-a49c-0d88df3f7391"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Exploring the resulting images, we can see that the results are not much different between the two models, at least on our small sample dataset.
