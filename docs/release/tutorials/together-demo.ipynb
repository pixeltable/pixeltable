# %% [markdown]
# # Integrate with Together.ai
#
# Pixeltable's Together.ai integration enables you to access advanced large language models (LLMs) hosted on the Together.ai platform.
#
# ### Prerequisites
# - A Together account with an API key (https://api.together.ai/settings/api-keys)
# - The `together` and `fireworks` Python library installed.
#
# ### Important Notes
#
# Together.ai usage may incur costs based on your Together.ai plan.
# Be mindful of sensitive data and consider security measures when integrating with external services.

# %%
# Required librairies
# %pip install -q pixeltable --upgrade together

# %%
# Initialize Pixeltable client and create a directory
import os
import getpass
import pixeltable as pxt
cl = pxt.Client()
cl.create_dir('dir_together', ignore_errors=True)
# Out:
# Creating a Pixeltable instance at: /root/.pixeltable
# Connected to Pixeltable database at: postgresql://postgres:@/pixeltable?host=/root/.pixeltable/pgdata
# Created directory `dir_together`.

# %% [markdown]
# Securely store your Together.ai API key by not hardcoding it into the notebook.

# %%
# Dynamically input your API Key as needed
if "TOGETHER_API_KEY" not in os.environ:
    os.environ["TOGETHER_API_KEY"] = getpass.getpass("Together API Key:")
# Out:
# Together API Key:··········

# %% [markdown]
# ## Completions

# %%
from pixeltable.functions.together import completions

# %% [markdown]
# Create a Table: In Pixeltable, create a table with columns to  represent your input data and the columns where you want to store the results from Fireworks.

# %%
 # Create a table in Pixeltable and pick a model hosted on Together with some parameters
complete = cl.create_table('table_completion', {'input': pxt.StringType()})

complete.add_column(output=completions(
    prompt=complete.input,
    model='mistralai/Mixtral-8x7B-v0.1',
    max_tokens=300,
    stop=['\n'],
    temperature=0.7,
    top_p=0.9,
    top_k=40,
    repetition_penalty=1.1,
    logprobs=1,
    echo=True,
    n=3,
))
# Out:
# Created table `table_completion`.
# Added 0 column values with 0 errors.
# UpdateStatus(num_rows=0, num_computed_values=0, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
complete.describe()
# Out:
# <style type="text/css">
# #T_81e96 th {
#   text-align: center;
# }
# #T_81e96_row0_col0, #T_81e96_row0_col1, #T_81e96_row0_col2, #T_81e96_row1_col0, #T_81e96_row1_col1, #T_81e96_row1_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_81e96" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_81e96_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_81e96_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_81e96_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81e96_row0_col0" class="data row0 col0" >input</td>
#       <td id="T_81e96_row0_col1" class="data row0 col1" >string</td>
#       <td id="T_81e96_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_81e96_row1_col0" class="data row1 col0" >output</td>
#       <td id="T_81e96_row1_col1" class="data row1 col1" >json</td>
#       <td id="T_81e96_row1_col2" class="data row1 col2" >completions(input, repetition_penalty=1.1, echo=True, top_p=0.9, temperature=0.7, stop=[
# ], top_k=40, logprobs=1, n=3, max_tokens=300, model='mistralai/Mixtral-8x7B-v0.1')</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Parse the bot response (output) into a new column
complete['response'] = complete.output.choices[0].text
# Out:
# Added 0 column values with 0 errors.

# %%
# Start a conversation
question = complete.insert(input="I want to rule")
answer = complete.select(complete.input, complete.response).show()
answer
# Out:
# Computing cells: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00,  4.38 cells/s]
# Inserting rows into `table_completion`: 1 rows [00:00, 241.90 rows/s]
# Computing cells: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00,  4.24 cells/s]
# Inserted 1 row with 0 errors.
#             input                                           response
# 0  I want to rule   out the possibility that this is just a coinc...

# %% [markdown]
# ## Chat Completions

# %%
from pixeltable.functions.together import chat_completions

# %%
 # Create a table in Pixeltable and pick a model hosted on Together with some parameters
chat = cl.create_table('table_chat', {'input': pxt.StringType()})
messages = [{'role': 'user', 'content': chat.input}]
chat.add_column(output=chat_completions(
    messages=messages,
    model='mistralai/Mixtral-8x7B-Instruct-v0.1',
    max_tokens=300,
    stop=['\n'],
    temperature=0.7,
    top_p=0.9,
    top_k=40,
    repetition_penalty=1.1,
    logprobs=1,
    echo=True,
    n=3,
))
# Out:
# Created table `table_chat`.
# Added 0 column values with 0 errors.
# UpdateStatus(num_rows=0, num_computed_values=0, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
chat.describe()
# Out:
# <style type="text/css">
# #T_938b5 th {
#   text-align: center;
# }
# #T_938b5_row0_col0, #T_938b5_row0_col1, #T_938b5_row0_col2, #T_938b5_row1_col0, #T_938b5_row1_col1, #T_938b5_row1_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_938b5" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_938b5_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_938b5_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_938b5_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_938b5_row0_col0" class="data row0 col0" >input</td>
#       <td id="T_938b5_row0_col1" class="data row0 col1" >string</td>
#       <td id="T_938b5_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_938b5_row1_col0" class="data row1 col0" >output</td>
#       <td id="T_938b5_row1_col1" class="data row1 col1" >json</td>
#       <td id="T_938b5_row1_col2" class="data row1 col2" >chat_completions([{'role': 'user', 'content': input}], repetition_penalty=1.1, echo=True, top_p=0.9, temperature=0.7, top_k=40, stop=[
# ], logprobs=1, n=3, max_tokens=300, model='mistralai/Mixtral-8x7B-Instruct-v0.1')</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Parse the bot response (output) into a new column
chat['response'] = chat.output.choices[0].message.content
# Out:
# Added 0 column values with 0 errors.

# %%
# Start a conversation
question = chat.insert(input="Can you make me a coffee?")
answer = chat.select(chat.input, chat.response).show()
answer
# Out:
# Computing cells: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00,  2.28 cells/s]
# Inserting rows into `table_chat`: 1 rows [00:00, 186.26 rows/s]
# Computing cells: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00,  2.24 cells/s]
# Inserted 1 row with 0 errors.
#                        input  \
# 0  Can you make me a coffee?
#
#                                             response
# 0   I'm sorry for any confusion, but I'm unable t...

# %% [markdown]
# ## Embeddings

# %%
from pixeltable.functions.together import embeddings

# %%
embed = cl.create_table('test_embeddings', {'input': pxt.StringType()})
embed.add_column(embed=embeddings(
      input=embed.input,
      model='togethercomputer/m2-bert-80M-8k-retrieval'))
# Out:
# Created table `test_embeddings`.
# Added 0 column values with 0 errors.
# UpdateStatus(num_rows=0, num_computed_values=0, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
embed.insert(input='Together AI provides a variety of embeddings models.')
# Out:
# Computing cells: 100%|████████████████████████████████████████████| 1/1 [00:01<00:00,  1.35s/ cells]
# Inserting rows into `test_embeddings`: 1 rows [00:00, 253.02 rows/s]
# Computing cells: 100%|████████████████████████████████████████████| 1/1 [00:01<00:00,  1.36s/ cells]
# Inserted 1 row with 0 errors.
# UpdateStatus(num_rows=1, num_computed_values=1, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
embed.describe()
embed.head()
# Out:
# <style type="text/css">
# #T_e77ab th {
#   text-align: center;
# }
# #T_e77ab_row0_col0, #T_e77ab_row0_col1, #T_e77ab_row0_col2, #T_e77ab_row1_col0, #T_e77ab_row1_col1, #T_e77ab_row1_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_e77ab" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_e77ab_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_e77ab_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_e77ab_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e77ab_row0_col0" class="data row0 col0" >input</td>
#       <td id="T_e77ab_row0_col1" class="data row0 col1" >string</td>
#       <td id="T_e77ab_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_e77ab_row1_col0" class="data row1 col0" >embed</td>
#       <td id="T_e77ab_row1_col1" class="data row1 col1" >array((None,), dtype=FLOAT)</td>
#       <td id="T_e77ab_row1_col2" class="data row1 col2" >together.embeddings(input, model='togethercomputer/m2-bert-80M-8k-retrieval')</td>
#     </tr>
#   </tbody>
# </table>
#                                                input  \
# 0  Together AI provides a variety of embeddings m...
#
#                                                embed
# 0  [0.016232457, -0.20974171, 0.20096539, 0.15308...

# %% [markdown]
# ## Image Generations

# %%
from pixeltable.functions.together import image_generations

# %%
image= cl.create_table('image_generation', {'input': pxt.StringType(), 'negative_prompt': pxt.StringType(nullable=True)}
  )
image.add_column(img=image_generations(image.input, model='runwayml/stable-diffusion-v1-5'))
image.add_column(img_2=image_generations(
image.input,
model='stabilityai/stable-diffusion-2-1',
steps=30,
seed=4178780,
height=768,
width=512,
negative_prompt=image.negative_prompt
  ))
# Out:
# Created table `image_generation`.
# Added 0 column values with 0 errors.
# Added 0 column values with 0 errors.
# UpdateStatus(num_rows=0, num_computed_values=0, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
# Start generating Images
image.insert([
  {'input': 'A friendly dinosaur playing tennis in a cornfield'},
  {'input': 'A friendly dinosaur playing tennis in a cornfield',
    'negative_prompt': 'tennis court'}
])
# Out:
# Inserting rows into `image_generation`: 2 rows [00:00, 837.60 rows/s]
# Inserted 2 rows with 0 errors.
# UpdateStatus(num_rows=2, num_computed_values=0, num_excs=0, updated_cols=[], cols_with_excs=[])

# %%
image.describe()
inputs = image.select(image.input, image.negative_prompt).show()
inputs
# Out:
# <style type="text/css">
# #T_6d5b8 th {
#   text-align: center;
# }
# #T_6d5b8_row0_col0, #T_6d5b8_row0_col1, #T_6d5b8_row0_col2, #T_6d5b8_row1_col0, #T_6d5b8_row1_col1, #T_6d5b8_row1_col2, #T_6d5b8_row2_col0, #T_6d5b8_row2_col1, #T_6d5b8_row2_col2, #T_6d5b8_row3_col0, #T_6d5b8_row3_col1, #T_6d5b8_row3_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_6d5b8" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_6d5b8_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_6d5b8_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_6d5b8_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d5b8_row0_col0" class="data row0 col0" >input</td>
#       <td id="T_6d5b8_row0_col1" class="data row0 col1" >string</td>
#       <td id="T_6d5b8_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_6d5b8_row1_col0" class="data row1 col0" >negative_prompt</td>
#       <td id="T_6d5b8_row1_col1" class="data row1 col1" >string</td>
#       <td id="T_6d5b8_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_6d5b8_row2_col0" class="data row2 col0" >img</td>
#       <td id="T_6d5b8_row2_col1" class="data row2 col1" >image</td>
#       <td id="T_6d5b8_row2_col2" class="data row2 col2" >image_generations(input, model='runwayml/stable-diffusion-v1-5')</td>
#     </tr>
#     <tr>
#       <td id="T_6d5b8_row3_col0" class="data row3 col0" >img_2</td>
#       <td id="T_6d5b8_row3_col1" class="data row3 col1" >image</td>
#       <td id="T_6d5b8_row3_col2" class="data row3 col2" >image_generations(input, width=512, seed=4178780, negative_prompt=negative_prompt, steps=30, height=768, model='stabilityai/stable-diffusion-2-1')</td>
#     </tr>
#   </tbody>
# </table>
#                                                input negative_prompt
# 0  A friendly dinosaur playing tennis in a cornfield            None
# 1  A friendly dinosaur playing tennis in a cornfield    tennis court

# %%
image.head(3)
# Out:
#                                                input negative_prompt  \
# 0  A friendly dinosaur playing tennis in a cornfield            None
# 1  A friendly dinosaur playing tennis in a cornfield    tennis court
#
#                                                  img  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                                img_2
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %% [markdown]
# ### Learn More
#
# To learn more about advanced techniques like RAG operations in Pixeltable, visit: https://pixeltable.readme.io/docs/rag-operations-in-pixeltable.
#
# You can also look at how to work with images in Pixeltable: https://pixeltable.readme.io/docs/working-with-images
#
# If you have any questions, don't hesitate to reach out.
