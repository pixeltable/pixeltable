# %%
import pixeltable as pxt

import os

os.environ['PIXELTABLE_DB'] = 'random_ops1'

l = pxt.list_tables('', recursive=True);
print(l)
# Out:
# ['view_63', 'view_90', 'view_99', 'tbl_2', 'view_41', 'tbl_0', 'view_49', 'view_7', 'view_14', 'view_15', 'view_64', 'tbl_1', 'view_26', 'view_37', 'view_67', 'view_40', 'view_58', 'view_93', 'view_39', 'view_92', 'view_32', 'view_44', 'view_82', 'tbl_3']

# %%
t = pxt.get_table('view_93')
t.tail()
# Out:
#    pos  frame_idx  pos_msec  pos_frame  \
# 0  451        451   18040.0        451
# 1  452        452   18080.0        452
# 2  453        453   18120.0        453
# 3  454        454   18160.0        454
# 4  455        455   18200.0        455
# 5  456        456   18240.0        456
# 6  457        457   18280.0        457
# 7  458        458   18320.0        458
# 8  459        459   18360.0        459
# 9  460        460   18400.0        460
#
#                                                frame           c24  \
# 0  <PIL.Image.Image image mode=RGB size=640x360 a...  9.990613e+08
# 1  <PIL.Image.Image image mode=RGB size=640x360 a...  9.990613e+08
# 2  <PIL.Image.Image image mode=RGB size=640x360 a...  9.990613e+08
# 3  <PIL.Image.Image image mode=RGB size=640x360 a...  9.990613e+08
# 4  <PIL.Image.Image image mode=RGB size=640x360 a...  9.990613e+08
# 5  <PIL.Image.Image image mode=RGB size=640x360 a...  9.990613e+08
# ...
