# %% [markdown]
# # Extract text from PowerPoint, Word, and Excel files
#
# Transform office documents into searchable, analyzable text data.
#
# **What's in this recipe:**
# - Extract text from PPTX, DOCX, and XLSX files
# - Split documents by headings, paragraphs, or custom limits
# - Preserve document structure and metadata for analysis

# %% [markdown]
# ## Problem
#
# You have office documents—presentations, reports, spreadsheets—that contain valuable text data. You need to extract this text to analyze content, search across documents, or feed into AI models.
#
# Manual extraction means opening each file, copying text, and losing structural information like headings and page boundaries. You need an automated way to process hundreds or thousands of office files while preserving their organization.

# %% [markdown]
# ## Solution
#
# You extract text from office documents using Pixeltable's document type with Microsoft's MarkItDown library. This converts PowerPoint, Word, and Excel files to structured text automatically.
#
# You can iterate on document processing before adding transformations to your table. Use `.select()` with `.collect()` to preview results on sample documents—nothing is stored in your table. If you want to collect only the first few rows, use `.head(n)` instead of `.collect()`. Once you're satisfied, use `DocumentSplitter` to split documents by headings, paragraphs, or token limits.

# %% [markdown]
# ### Setup

# %%
# For testing with local changes, run from repo root: uv pip install -e .
# %pip install -qU pixeltable markitdown[pptx,docx,xlsx]
# Out:
# zsh:1: no matches found: markitdown[pptx,docx,xlsx]
# Note: you may need to restart the kernel to use updated packages.

# %%
import pixeltable as pxt
from pixeltable.iterators.document import DocumentSplitter

# %%
# Download a sample PowerPoint file for demonstration
import urllib.request
import tempfile
import os

# Sample test file from Pixeltable repo
url = 'https://github.com/pixeltable/pixeltable/raw/main/tests/data/documents/test_presentation.pptx'
sample_pptx = os.path.join(tempfile.gettempdir(), 'test_presentation.pptx')
urllib.request.urlretrieve(url, sample_pptx)
print(f"Downloaded sample presentation: {sample_pptx}")
# Out:
# Created sample presentation: /var/folders/s4/0zdx499s6sv3_0jll6ccdbh00000gn/T/sample_presentation.pptx

# %% [markdown]
# ### Load office documents

# %%
# Create a fresh directory (drop existing if present)
pxt.drop_dir('office_docs', force=True)
pxt.create_dir('office_docs')
# Out:
# Creating a Pixeltable instance at: /Users/pjlb/.pixeltable
# Connected to Pixeltable database at: postgresql+psycopg://postgres:@/pixeltable?host=/Users/pjlb/.pixeltable/pgdata
# Created directory 'office_docs'.

# %%
# Create table for office documents
docs = pxt.create_table('office_docs.documents', {'doc': pxt.Document})
# Out:
# Created table 'documents'.

# %%
# Insert office files
# Using the sample presentation downloaded above
# Replace with your own PPTX, DOCX, or XLSX files
docs.insert([
    {'doc': sample_pptx},
])
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[6], line 4
#       1 # Insert office files
#       2 # Using the sample presentation we created above
#       3 # Replace with your own PPTX, DOCX, or XLSX files
# ----> 4 docs.insert([
#       5     {'doc': sample_pptx},
#       6 ])
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/catalog/insertable_table.py:174, in InsertableTable.insert(self, source, source_format, schema_overrides, on_error, print_stats, **kwargs)
#     171 data_source.add_table_info(table)
#     172 data_source.prepare_for_insert_into_table()
# --> 174 return table.insert_table_data_source(
#     175     data_source=data_source, fail_on_exception=fail_on_exception, print_stats=print_stats
#     176 )
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/catalog/insertable_table.py:194, in InsertableTable.insert_table_data_source(self, data_source, fail_on_exception, print_stats)
#     192         status = pxt.UpdateStatus()
#     193         for row_batch in data_source.valid_row_batch():
# --> 194             status += self._tbl_version.get().insert(
#     195                 rows=row_batch, query=None, print_stats=print_stats, fail_on_exception=fail_on_exception
#     196             )
#     198 Env.get().console_logger.info(status.insert_msg)
#     200 FileCache.get().emit_eviction_warnings()
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/catalog/table_version.py:1036, in TableVersion.insert(self, rows, query, print_stats, fail_on_exception)
#    1033         self.next_row_id += 1
#    1034         yield rowid
# -> 1036 result = self._insert(
#    1037     plan, time.time(), print_stats=print_stats, rowids=rowids(), abort_on_exc=fail_on_exception
#    1038 )
#    1039 return result
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/catalog/table_version.py:1053, in TableVersion._insert(self, exec_plan, timestamp, rowids, print_stats, abort_on_exc)
#    1051 # we're creating a new version
#    1052 self.bump_version(timestamp, bump_schema_version=False)
# -> 1053 cols_with_excs, row_counts = self.store_tbl.insert_rows(
#    1054     exec_plan, v_min=self.version, rowids=rowids, abort_on_exc=abort_on_exc
#    1055 )
#    1056 result = UpdateStatus(
#    1057     cols_with_excs=[f'{self.name}.{self.cols_by_id[cid].name}' for cid in cols_with_excs],
#    1058     row_count_stats=row_counts,
#    1059 )
#    1061 # update views
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/store.py:430, in StoreBase.insert_rows(self, exec_plan, v_min, show_progress, rowids, abort_on_exc)
#     428 if abort_on_exc and row.has_exc():
#     429     exc = row.get_first_exc()
# --> 430     raise exc
#     432 rowid = (next(rowids),) if rowids is not None else row.pk[:-1]
#     433 pk = (*rowid, v_min)
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/exprs/column_ref.py:266, in ColumnRef.eval(self, data_row, row_builder)
#     263     return
#     265 try:
# --> 266     self.col.col_type.validate_media(data_row.file_paths[unvalidated_slot_idx])
#     267     # access the value only after successful validation
#     268     val = data_row[unvalidated_slot_idx]
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/type_system.py:1301, in DocumentType.validate_media(self, val)
#    1298 assert isinstance(val, str)
#    1299 from pixeltable.utils.documents import get_document_handle
# -> 1301 _ = get_document_handle(val)
#
# File /opt/miniconda3/envs/pixeltable/lib/python3.11/site-packages/pixeltable/utils/documents.py:33, in get_document_handle(path)
#      30 if handle is not None:
#      31     return handle
# ---> 33 raise excs.Error(f'Unrecognized document format: {path}')
#
# Error: Unrecognized document format: /var/folders/s4/0zdx499s6sv3_0jll6ccdbh00000gn/T/sample_presentation.pptx

# %% [markdown]
# ### Extract full document text

# %% [markdown]
# #### Test extraction with a query
#
# Use `.select()` with `.head(1)` to preview text extraction from one document.

# %%
# Create a view to extract full document text
chunks = pxt.create_view(
    'office_docs.full_text',
    docs,
    iterator=DocumentSplitter.create(
        document=docs.doc,
        separators='',  # No splitting - extract full document
    )
)
# Out:
# Inserting rows into `full_text`: 1 rows [00:00, 287.69 rows/s]

# %%
# Preview extracted text from first document
chunks.select(chunks.doc, chunks.text).head(1)
# Out:
#                                                  doc  \
# 0  /Users/pierre/pixeltable/docs/resources/calpy....
#
#                                                 text
# 0  November 6 2025 Open-Source Data Infrastructur...

# %% [markdown]
# ### Split documents by headings

# %% [markdown]
# #### Test heading split with a query
#
# Use `.select()` with `.collect()` to preview how documents split by headings.

# %%
# Create view that splits by headings
chunks = pxt.create_view(
    'office_docs.by_heading',
    docs,
    iterator=DocumentSplitter.create(
        document=docs.doc,
        separators='heading',
        metadata='heading',  # Preserve heading structure
    )
)
# Out:
# Inserting rows into `by_heading`: 87 rows [00:00, 13241.81 rows/s]

# %%
# View chunks with their headings
# Each section under a heading becomes a separate chunk
chunks.select(chunks.doc, chunks.heading, chunks.text).collect()
# Out:
#                                                   doc  \
# 0   /Users/pierre/pixeltable/docs/resources/calpy....
# 1   /Users/pierre/pixeltable/docs/resources/calpy....
# 2   /Users/pierre/pixeltable/docs/resources/calpy....
# 3   /Users/pierre/pixeltable/docs/resources/calpy....
# 4   /Users/pierre/pixeltable/docs/resources/calpy....
# ..                                                ...
# 82  /Users/pierre/pixeltable/docs/resources/calpy....
# 83  /Users/pierre/pixeltable/docs/resources/calpy....
# 84  /Users/pierre/pixeltable/docs/resources/calpy....
# 85  /Users/pierre/pixeltable/docs/resources/calpy....
# 86  /Users/pierre/pixeltable/docs/resources/calpy....
#
#                                               heading  \
# 0                                                  {}
# 1   {'h1': 'Open-Source Data Infrastructure for Mu...
# 2   {'h1': 'Open-Source Data Infrastructure for Mu...
# 3                                  {'h1': 'About me'}
# 4                  {'h1': 'About me', 'h3': 'Notes:'}
# ..                                                ...
# 82             {'h1': 'Table-as-UDF', 'h3': 'Notes:'}
# 83  {'h1': '======================================...
# 84  {'h1': '======================================...
# 85  {'h1': 'Your one stop shop for developing AI-b...
# 86  {'h1': 'Your one stop shop for developing AI-b...
#
#                                                  text
# 0                                     November 6 2025
# 1   Open-Source Data Infrastructure for Multimodal...
# 2                                              Notes:
# 3   About me Co-founder & CTO, Pixeltable UC Berke...
# 4                                              Notes:
# ..                                                ...
# 82             Notes: udf will be the unit of serving
# 83  ==============================================...
# 84                                             Notes:
# 85  Your one stop shop for developing AI-based dat...
# 86                                             Notes:
#
# [87 rows x 3 columns]

# %% [markdown]
# ### Split by token limit for AI models

# %% [markdown]
# #### Test token limit with a query
#
# Use `.select()` with `.head(3)` to preview how documents split into token-sized chunks.

# %%
# Create view with token-based splitting
chunks = pxt.create_view(
    'office_docs.by_tokens',
    docs,
    iterator=DocumentSplitter.create(
        document=docs.doc,
        separators='heading,token_limit',  # Split by heading first, then by tokens
        limit=512,  # Maximum tokens per chunk
        overlap=50,  # Overlap between chunks to preserve context
        metadata='heading',
    )
)
# Out:
# Inserting rows into `by_tokens`: 2369 rows [00:00, 26816.76 rows/s]

# %%
# Preview first few chunks with token limits
# Each chunk is 512 tokens or less
chunks.select(chunks.doc, chunks.heading, chunks.text).head(3)
# Out:
#                                                  doc heading             text
# 0  /Users/pierre/pixeltable/docs/resources/calpy....      {}  November 6 2025
# 1  /Users/pierre/pixeltable/docs/resources/calpy....      {}           6 2025
# 2  /Users/pierre/pixeltable/docs/resources/calpy....      {}           6 2025

# %% [markdown]
# ### Search across all documents

# %%
# Find chunks containing specific keywords
# This searches across all office documents
chunks.where(chunks.text.contains('test')).select(chunks.doc, chunks.text).head(3)
# Out:
#                                                  doc  \
# 0  /Users/pierre/pixeltable/docs/resources/calpy....
# 1  /Users/pierre/pixeltable/docs/resources/calpy....
# 2  /Users/pierre/pixeltable/docs/resources/calpy....
#
#                                                 text
# 0  About me Co-founder & CTO, Pixeltable UC Berke...
# 1   Google (2003-2010): Tech lead for F1 database...
# 2   (2003-2010): Tech lead for F1 database, worke...

# %% [markdown]
# ## Explanation
#
# **Supported formats:**
# - PowerPoint: `.pptx`, `.ppt`
# - Word: `.docx`, `.doc`
# - Excel: `.xlsx`, `.xls`
#
# **Separator options:**
# - `heading` - Split by document headings (preserves structure)
# - `paragraph` - Split by paragraphs
# - `sentence` - Split by sentences
# - `token_limit` - Split by token count (requires `limit` parameter)
# - `char_limit` - Split by character count (requires `limit` parameter)
# - Multiple separators work together: `'heading,token_limit'` splits by heading first, then ensures no chunk exceeds token limit
#
# **Metadata fields:**
# - `heading` - Hierarchical heading structure (e.g., `{'h1': 'Introduction', 'h2': 'Overview'}`)
# - `title` - Document title
# - `sourceline` - Source line number (HTML and Markdown documents)
#
# **Token overlap:**
# The `overlap` parameter ensures chunks share context at boundaries. This prevents sentences from being split mid-thought when feeding chunks to AI models.

# %% [markdown]
# ## See also
#
# - [Get fast feedback on transformations](./dev-iterative-workflow.ipynb)
# - [Pixeltable Document API](https://docs.pixeltable.com/api/pixeltable/#pixeltable.Document)
