# %% [markdown]
# # Split documents into chunks for RAG
#
# Break PDFs and documents into searchable chunks for retrieval-augmented generation (RAG) pipelines.

# %% [markdown]
# ## Problem
#
# You have PDF documents or text files that you want to use for retrieval-augmented generation (RAG). Before you can search them, you need to:
#
# 1. Split documents into smaller chunks
# 2. Generate embeddings for each chunk
# 3. Store everything in a searchable index
#
# | Document | Size | Chunks needed |
# |----------|------|---------------|
# | annual_report.pdf | 50 pages | ~100 chunks |
# | user_manual.pdf | 20 pages | ~40 chunks |
# | research_paper.pdf | 10 pages | ~20 chunks |

# %% [markdown]
# ## Solution
#
# **What's in this recipe:**
# - Split PDFs into paragraphs or sentences
# - Control chunk size with token limits
# - Add embeddings for semantic search
#
# You create a view with a DocumentSplitter iterator that automatically breaks documents into chunks. Then you add an embedding index for semantic search.

# %% [markdown]
# ### Setup

# %%
# %pip install -qU pixeltable sentence-transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pixeltable as pxt
from pixeltable.iterators import DocumentSplitter
from pixeltable.functions.huggingface import sentence_transformer

# %% [markdown]
# ### Load documents

# %%
# Create a fresh directory
pxt.drop_dir('rag_demo', force=True)
pxt.create_dir('rag_demo')
# Out:
# Connected to Pixeltable database at: postgresql+psycopg://postgres:@/pixeltable?host=/Users/pjlb/.pixeltable/pgdata
# Created directory 'rag_demo'.

# %%
# Create table for documents
docs = pxt.create_table('rag_demo.documents', {'document': pxt.Document})
# Out:
# Created table 'documents'.

# %%
# Insert a sample PDF
docs.insert([
    {'document': 'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/resources/Argus-Market-Digest-June-2024.pdf'}
])
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Insert a sample PDF
# ----> 2 docs.insert([
#       3     {'document': 'https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/resources/Argus-Market-Digest-June-2024.pdf'}
#       4 ])
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/catalog/insertable_table.py:174, in InsertableTable.insert(self, source, source_format, schema_overrides, on_error, print_stats, **kwargs)
#     171 data_source.add_table_info(table)
#     172 data_source.prepare_for_insert_into_table()
# --> 174 return table.insert_table_data_source(
#     175     data_source=data_source, fail_on_exception=fail_on_exception, print_stats=print_stats
#     176 )
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/catalog/insertable_table.py:194, in InsertableTable.insert_table_data_source(self, data_source, fail_on_exception, print_stats)
#     192         status = pxt.UpdateStatus()
#     193         for row_batch in data_source.valid_row_batch():
# --> 194             status += self._tbl_version.get().insert(
#     195                 rows=row_batch, query=None, print_stats=print_stats, fail_on_exception=fail_on_exception
#     196             )
#     198 Env.get().console_logger.info(status.insert_msg)
#     200 FileCache.get().emit_eviction_warnings()
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/catalog/table_version.py:1036, in TableVersion.insert(self, rows, query, print_stats, fail_on_exception)
#    1033         self.next_row_id += 1
#    1034         yield rowid
# -> 1036 result = self._insert(
#    1037     plan, time.time(), print_stats=print_stats, rowids=rowids(), abort_on_exc=fail_on_exception
#    1038 )
#    1039 return result
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/catalog/table_version.py:1053, in TableVersion._insert(self, exec_plan, timestamp, rowids, print_stats, abort_on_exc)
#    1051 # we're creating a new version
#    1052 self.bump_version(timestamp, bump_schema_version=False)
# -> 1053 cols_with_excs, row_counts = self.store_tbl.insert_rows(
#    1054     exec_plan, v_min=self.version, rowids=rowids, abort_on_exc=abort_on_exc
#    1055 )
#    1056 result = UpdateStatus(
#    1057     cols_with_excs=[f'{self.name}.{self.cols_by_id[cid].name}' for cid in cols_with_excs],
#    1058     row_count_stats=row_counts,
#    1059 )
#    1061 # update views
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/store.py:421, in StoreBase.insert_rows(self, exec_plan, v_min, show_progress, rowids, abort_on_exc)
#     418 table_rows: list[tuple[Any]] = []
#     419 exec_plan.open()
# --> 421 for row_batch in exec_plan:
#     422     num_rows += len(row_batch)
#     423     batch_table_rows: list[tuple[Any]] = []
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/exec_node.py:58, in ExecNode.__iter__(self)
#      56 try:
#      57     while True:
# ---> 58         batch: DataRowBatch = loop.run_until_complete(aiter.__anext__())
#      59         yield batch
#      60 except StopAsyncIteration:
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/nest_asyncio.py:99, in _patch_loop.<locals>.run_until_complete(self, future)
#      96 if not f.done():
#      97     raise RuntimeError(
#      98         'Event loop stopped before Future completed.')
# ---> 99 return f.result()
#
# File /opt/miniconda3/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /opt/miniconda3/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/object_store_save_node.py:119, in ObjectStoreSaveNode.__aiter__(self)
#     116 while True:
#     117     # Create work to fill the queue to the high water mark ... ?without overrunning the in-flight row limit.
#     118     while not self.input_finished and self.queued_work < self.QUEUE_DEPTH_HIGH_WATER:
# --> 119         input_batch = await self.get_input_batch(input_iter)
#     120         if input_batch is not None:
#     121             self.__process_input_batch(input_batch, executor)
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/object_store_save_node.py:105, in ObjectStoreSaveNode.get_input_batch(self, input_iter)
#     103 """Get the next batch of input rows, or None if there are no more rows"""
#     104 try:
# --> 105     input_batch = await anext(input_iter)
#     106     if input_batch is None:
#     107         self.input_finished = True
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/expr_eval/expr_eval_node.py:289, in ExprEvalNode.__aiter__(self)
#     287         raise self.error from self.error.exc
#     288     else:
# --> 289         raise self.error
#     290 if completed_aw in done:
#     291     self._log_state('completed_aw done')
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/expr_eval/expr_eval_node.py:118, in ExprEvalNode._fetch_input_batch(self)
#     116 assert not self.input_complete
#     117 try:
# --> 118     batch = await anext(self.input_iter)
#     119     assert self.next_input_batch is None
#     120     if self.current_input_batch is None:
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/cache_prefetch_node.py:105, in CachePrefetchNode.__aiter__(self)
#     103 while self.queued_work > self.QUEUE_DEPTH_LOW_WATER or (self.input_finished and self.queued_work > 0):
#     104     done, _ = futures.wait(self.in_flight_requests, return_when=futures.FIRST_COMPLETED)
# --> 105     self.__process_completions(done, ignore_errors=self.ctx.ignore_errors)
#     107 # Emit results to meet batch size requirements or empty the in-flight row queue
#     108 if self.__has_ready_batch() or (
#     109     len(self.ready_rows) > 0 and self.input_finished and self.queued_work == 0
#     110 ):
#     111     # create DataRowBatch from the first BATCH_SIZE ready rows
#
# File /Users/pierre/pixeltable/.venv/lib/python3.12/site-packages/pixeltable/exec/cache_prefetch_node.py:146, in CachePrefetchNode.__process_completions(self, done, ignore_errors)
#     144 tmp_path, exc = f.result()
#     145 if exc is not None and not ignore_errors:
# --> 146     raise exc
#     147 local_path: Path | None = None
#     148 if tmp_path is not None:
#     149     # register the file with the cache for the first column in which it's missing
#
# Error: Failed to download https://raw.githubusercontent.com/pixeltable/pixeltable/main/docs/resources/Argus-Market-Digest-June-2024.pdf: HTTP Error 404: Not Found

# %% [markdown]
# ### Split into chunks
#
# Create a view that splits each document into paragraphs with a token limit:

# %%
# Create a view that splits documents into chunks
chunks = pxt.create_view(
    'rag_demo.chunks',
    docs,
    iterator=DocumentSplitter.create(
        document=docs.document,
        separators='paragraph',  # Split by paragraph
        limit=300  # Max 300 tokens per chunk
    )
)

# %%
# View the chunks
chunks.select(chunks.text).head(5)

# %% [markdown]
# ### Add semantic search
#
# Create an embedding index on the chunks for similarity search:

# %%
# Add embedding index for semantic search
chunks.add_embedding_index(
    column='text',
    string_embed=sentence_transformer.using(model_id='all-MiniLM-L6-v2')
)

# %% [markdown]
# ### Search your documents
#
# Use similarity search to find relevant chunks:

# %%
# Search for relevant chunks
query = "market trends"
sim = chunks.text.similarity(query)

results = (
    chunks
    .order_by(sim, asc=False)
    .select(chunks.text, score=sim)
    .limit(3)
)
results.collect()

# %% [markdown]
# ## Explanation
#
# **Separator options:**
#
# | Separator | Description |
# |-----------|-------------|
# | `paragraph` | Split on paragraph breaks |
# | `sentence` | Split on sentence boundaries |
# | `heading` | Split on document headings |
# | `page` | Split on page breaks |
# | `token_limit` | Split at token count only |
#
# You can combine separators: `separators='paragraph,token_limit'`
#
# **Chunk sizing:**
#
# - `limit`: Maximum tokens per chunk (default: 500)
# - `overlap`: Tokens to overlap between chunks (default: 0)
#
# **New documents are processed automatically:**
#
# When you insert new documents, chunks and embeddings are generated without extra code.

# %% [markdown]
# ## See also
#
# - [Iterators documentation](https://docs.pixeltable.com/datastore/iterators)
# - [RAG demo notebook](https://docs.pixeltable.com/notebooks/use-cases/rag-demo)
